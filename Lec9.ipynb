# %%
lst = [3, 15, 41, 23, 71, 34, 67]
largest = lst[0]
for i in range (1, 7): 
    if largest < lst [i]:
        largest = lst[i]
print (f'Largest: {largest}')
# Out:
# Largest: 71

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
largest = lst[0]
for item in lst: 
    if largest < item:
        largest = item
print (f'Largest: {largest}')
# Out:
# Largest: 71

# %% [markdown]
# lst = [3, 15, 41, 23, 71, 34, 67]
# cnt = 0
#
# for item in lst:
#     cnt += 1

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
cnt = 0

for item in lst: 
    cnt += 1
print (cnt)
# Out:
# 7

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
print (len(lst))
# Out:
# 7

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
for index, item in enumerate(lst):
    print (index+1, item)
# Out:
# 1 3
# 2 15
# 3 41
# 4 23
# 5 71
# 6 34
# 7 67

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
sum = 0
for item in lst:
    sum += item
print (f'Sum: {sum}')
# Out:
# Sum: 254

# %%
fact = 1
for i in range (2, 6):
    fact *= i
print (f'Factorial: {fact}')
# Out:
# Factorial: 120

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
sum = 0
for item in lst:
    sum += item
print (f'Sum: {sum}')
avg = sum/len(lst)
print ('Avg: {:.2f}'.format(avg))
# Out:
# Sum: 254
# Avg: 36.29

# %%
lst = [3, 15, 41, 23, 71, 34, 67]
largest = None
for i in range (1, 7):
    if largest is None:
        largest = lst[i]
    elif largest < lst [i]:
        largest = lst[i]
print (f'Largest: {largest}')
# Out:
# Largest: 71

# %%
num = int(input('Number: '))
for i in range (1, 11):
    print (f'{num}x{i}={num*i}')
# Out:
# Number:  12
# 12x1=12
# 12x2=24
# 12x3=36
# 12x4=48
# 12x5=60
# 12x6=72
# 12x7=84
# 12x8=96
# 12x9=108
# 12x10=120
