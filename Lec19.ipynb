# %%
with open ('/home/dean/Desktop/Lecture/Python NU/SampleQuestions.txt', 'r') as file:
    for line in file:
        print (line)
file.close()
# Out:
# 1. Write a Python program to read the file and print all the rows.
#
# 2. Write a Python program to extract the data for their respective columns.
#
# 3. Write a program to extract and display all unique teachers from the Teacher column.
#
# 4. Write a script to find all students enrolled in the course BUS 102.
#
# 5. Calculate the number of students in each course.
#
# 6. Count how many students applied for the exam.
#
# 7. Find all students who applied on or after a specific date, e.g., 10-05-2024.
#
# 8. Write a program to find and display the number of exam a student is attempting.
#
# 9. Identify all students with an overlap course.
#
# 10. Identify the most popular course (the one with the highest number of students).
#
# 11. Count how many unique courses each teacher is handling.
#
# sdfsdfas asdf asdfasdf asdfsad fasdf sadf

# %%
try:
    with open ('Output.txt', 'r') as file:
        content = file.read ()
        print (content)
except FileNotFoundError:
    print ('File does not exist')
finally:
    file.close()
# Out:
# Hello!
# Hello!

# %%
import pandas as pd

df = pd.read_csv ('SampleFile.csv')
cols = df.columns
values = df.values
#print (values)

'''
for value in values:
    print (value) 
'''

programs = df['Program']
print (set(programs))
# Out:
# {'LL.M', 'ENGLISH', 'EEE (Diploma- Weekend)', 'BSS (JMC)', 'CSE(Regular)', 'LL.B. (Hons)', 'Textile Engg (Regular)', 'EEE (Regular)', 'Textile Engg(Dip-Weekend)', 'BBA', 'BSS(S)', 'MBA', 'CSE (Diploma- Weekend)'}
