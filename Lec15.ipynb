# %%
import random

NUM = 100

lst = list () 
for i in range (NUM):
    lst.append (random.randint(0,100))

print (lst)

mset = set (lst)
print (mset)
print (len(mset))

'''
for item in mset:
    print (item)
'''
# Out:
# [51, 47, 70, 96, 53, 62, 52, 54, 86, 92, 17, 61, 71, 90, 75, 31, 40, 42, 10, 16, 40, 37, 70, 94, 12, 66, 12, 63, 31, 72, 66, 4, 28, 1, 68, 94, 39, 23, 53, 11, 8, 39, 30, 60, 30, 57, 82, 90, 20, 56, 100, 2, 59, 86, 43, 19, 17, 100, 53, 37, 28, 87, 50, 6, 47, 4, 26, 98, 20, 67, 80, 73, 12, 23, 54, 90, 94, 19, 86, 65, 36, 14, 82, 68, 94, 79, 69, 13, 42, 28, 100, 83, 57, 39, 39, 78, 95, 60, 96, 74]
# {1, 2, 4, 6, 8, 10, 11, 12, 13, 14, 16, 17, 19, 20, 23, 26, 28, 30, 31, 36, 37, 39, 40, 42, 43, 47, 50, 51, 52, 53, 54, 56, 57, 59, 60, 61, 62, 63, 65, 66, 67, 68, 69, 70, 71, 72, 73, 74, 75, 78, 79, 80, 82, 83, 86, 87, 90, 92, 94, 95, 96, 98, 100}
# 63
# '\nfor item in mset:\n    print (item)\n'

# %%
import random

NUM = 10

ms = set() 
for i in range (NUM):
    ms.add(random.randint(0,10))

print (ms)
ms.clear()
print (ms)
# Out:
# {2, 3, 7, 8, 9}
# set()

# %%
sw = set()

for i in range (5):
    sw.add(input(f'{i+1}: put a word: '))

for word in sw:
    print (f'{word.lower()}')
    print (f'{word.upper()}')
# Out:
# 1: put a word:  sdfd
# 2: put a word:  Adfgfg
# 3: put a word:  fdfR
# 4: put a word:  dfdfgh
# 5: put a word:  jkhjk
# adfgfg
# ADFGFG
# jkhjk
# JKHJK
# fdfr
# FDFR
# dfdfgh
# DFDFGH
# sdfd
# SDFD

# %%
import random

sw = {i for i in range (100) if i % 3 == 0 if i % 7 == 0}
print (sw)
# Out:
# {0, 42, 84, 21, 63}

# %%
names = {'sdfasd', 'sdfsda', 'fhfghfa', 'jkjkj', 'ghjhj'}
new_names = {name for name in names if name.endswith('a')}
print (new_names)
# Out:
# {'sdfsda', 'fhfghfa'}
