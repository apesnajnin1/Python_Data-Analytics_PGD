# %%
print ('Mst. Najnin Sultana')
# Out:
# Mst. Najnin Sultana

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
  print(f'User uploaded file "{filename}" with length {len(uploaded[filename])} bytes')
  # Once uploaded, you can read the file, for example, a CSV file with pandas:
  # import pandas as pd
  # df = pd.read_csv(filename)
  # display(df.head())
# Out:
#      <input type="file" id="files-193b28f0-6376-48f7-bad4-f28c6852ca43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-193b28f0-6376-48f7-bad4-f28c6852ca43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# After running the cell above, a file browser widget will appear. You can use it to select and upload your downloaded file.
#
# Once the file is uploaded, you can access it by its filename. For example, if you uploaded a CSV file named `my_data.csv`, you can read it into a pandas DataFrame like this:

# %%
import pandas as pd

# Replace 'your_file.csv' with the actual name of your uploaded file
# For example, if you uploaded 'my_data.csv':
# df = pd.read_csv('my_data.csv')
# display(df.head())

# If it's a text file:
# with open('your_file.txt', 'r') as f:
#     content = f.read()
#     print(content)

# %%
chocolate = 'najnin'
print (chocolate)
# Out:
# najnin

# %%
boy = 'Rakeen'
print (boy)
# Out:
# Rakeen

# %%
# we are lerning variable
name = 'najnin'
print (name)
# Out:
# najnin

# %%
'''
sdfgdfhdf
gdfhbdfjfg
hfjfgmjkfg
'''

price = 300
print ( price)
# Out:
# 300

# %%
name = input ('Write down your name')
print (name)
# Out:
# Write down your name   Mst. Najnin Sultana
#    Mst. Najnin Sultana
