# %%
language = ['python', 'C++', 'JavaScript', 'C#', 'C', 'Java']
language.append('HTML')
print (language)
language.remove('HTML')
print (language)
language[2] = 'R'
print (language)

for lan in language:
    print (lan)
# Out:
# ['python', 'C++', 'JavaScript', 'C#', 'C', 'Java', 'HTML']
# ['python', 'C++', 'JavaScript', 'C#', 'C', 'Java']
# ['python', 'C++', 'R', 'C#', 'C', 'Java']
# python
# C++
# R
# C#
# C
# Java

# %%
Names = list()
 
for i in range (0, 5):
    name = input (f'{i+1}: put a name: ')
    Names.append(name)
print (Names)

for name in Names:
    print (name.upper())
# Out:
# 1: put a name:  fd
# 2: put a name:  fhty
# 3: put a name:  werew
# 4: put a name:  yuy
# 5: put a name:  e4rte
# ['fd', 'fhty', 'werew', 'yuy', 'e4rte']
# FD
# FHTY
# WEREW
# YUY
# E4RTE

# %%
import random

MAX = 10

Numbers = list()

for i in range (0, MAX+1):
    Numbers.append(random.randint(0, 101))
print (Numbers)

for num in Numbers:
    if num % 2 == 0:
        print (num)
# Out:
# [51, 58, 47, 76, 93, 9, 80, 79, 33, 51, 12]
# 58
# 76
# 80
# 12

# %%
Names = list()
 
for i in range (0, 5):
    name = input (f'{i+1}: put a name: ')
    Names.append(name)
print (Names)

vowel = ['a', 'e', 'i', 'o', 'u']
for name in Names:
    if name in vowel:
        print (name)
# Out:
# 1: put a name:  aei
# 2: put a name:  dfgdfg
# 3: put a name:  hgfg
# 4: put a name:  dfg
# 5: put a name:  dfgf
# ['aei', 'dfgdfg', 'hgfg', 'dfg', 'dfgf']

# %%
import random

MAX = 10

Numbers = list()

for i in range (0, MAX):
    Numbers.append(random.randint(0, 101))
print (Numbers)

for num in Numbers:
    if num >= 10 and num <= 20:
        print (num)
# Out:
# [76, 48, 99, 63, 51, 51, 82, 63, 13, 93]
# 13

# %%
import random

MAX = 10

Numbers = list()

for i in range (0, MAX):
    Numbers.append(random.randint(0, 101))
print (Numbers)

Numbers1 = Numbers.copy()
print (Numbers1)

Numbers.clear()
print (Numbers)
print (Numbers1)
# Out:
# [45, 9, 101, 101, 82, 81, 50, 68, 4, 79]
# [45, 9, 101, 101, 82, 81, 50, 68, 4, 79]
# []
# [45, 9, 101, 101, 82, 81, 50, 68, 4, 79]

# %%
Names = list()
 
for i in range (0, 5):
    name = input (f'{i+1}: put a name: ')
    Names.append(name)
print (Names)

vowel = ['a', 'e', 'i', 'o', 'u']
for name in Names:
    if name in ''vowel:
        print (name)
# Out:
# 1: put a name:  aei
# 2: put a name:  dfgfd
# 3: put a name:  ghgf
# 4: put a name:  erew
# 5: put a name:  dfgdf
# ['aei', 'dfgfd', 'ghgf', 'erew', 'dfgdf']
# aei

# %%
message = 'You are being informed of a recent request from the Bangladesh Accreditation Council (BAC) regarding the collection of information from faculty members (Professors) who are interested in contributing to Quality Assurance (QA) related academic accreditation activities.'
words = message.split()
cnt = len(words)
print (cnt)
# Out:
# 36

# %%
lst = ['Python', 'C++', 'JavaScript', 'C', 'Java', 'HTML']
 
for i in range (len(lst)):
    popped_item = lst.pop()
    print (popped_item)
    print (lst)
# Out:
# HTML
# ['Python', 'C++', 'JavaScript', 'C', 'Java']
# Java
# ['Python', 'C++', 'JavaScript', 'C']
# C
# ['Python', 'C++', 'JavaScript']
# JavaScript
# ['Python', 'C++']
# C++
# ['Python']
# Python
# []

# %%
lst = ['Python', 'C++', 'JavaScript', 'C', 'Java', 'HTML']
 
for i in range (len(lst)):
    popped_item = lst.pop()
    print (popped_item)
    print (lst)
# Out:
# HTML
# ['Python', 'C++', 'JavaScript', 'C', 'Java']
# Java
# ['Python', 'C++', 'JavaScript', 'C']
# C
# ['Python', 'C++', 'JavaScript']
# JavaScript
# ['Python', 'C++']
# C++
# ['Python']
# Python
# []
