# %%
x = 0
if x == 20 - 20:
    print ('Condition is true')
    print ('Hello World!')

# %%
x = 5
if x != 10:
    print ('{} is smaller than 10'.format(x))
if x > 20:
    print ('{} is bigger than 20'.format(x))
# Out:
# 5 is smaller than 10

# %%
x = 10
if x > 5 or x < 11:
    print ('{} is within 5 to 11'.format (x))
if x < 5 or x < 11:
    print ('{} is less than 5 and 11'.format (x))
if x > 5 or x > 11:
    print ('{} is greater than 5 and 11'.format (x))
if x < 5 or x > 11:
    print ('{} is greater than 5 and 11'.format (x))
# Out:
# 10 is within 5 to 11
# 10 is less than 5 and 11
# 10 is greater than 5 and 11

# %%
num1 = int (input('Put a number: '))
num2 = int (input('Put a number: '))

if num1 < num2:
    print ('{} is the maximum number'.format(num2))
else:
    print ('{} is the maximum number'.format(num1))
# Out:
# Put a number:  45
# Put a number:  78
# 78 is the maximum number

# %%
marks = int (input('Put a marks: '))
if marks >= 80:
    print ('A+')
elif marks >= 75 and marks < 80:
    print ('A')
elif marks >= 70 and marks < 75:
    print ('A-')
elif marks >= 65 and marks < 70:
    print ('B+')
elif marks >= 60 and marks < 65:
    print ('B')
elif marks >= 55 and marks < 60:
    print ('B-')
else:
    print ('Check the mark and input again')
# Out:
# Put a marks:  23
# Check the mark and input again

# %%
num = int (input ('Put an integer number: '))
if num % 2 == 0:
    print ('{} is an even number'.format(num))
else:
    print ('{} is an odd number'.format(num))
# Out:
# Put an integer number:  22256808
# 22256808 is an even number

# %%
score = int (input ('Put an integer number: '))
if score >= 50:
    print ('{} is a passing score'.format(score))
else:
    print ('{} is a failing score'.format(score))
# Out:
# Put an integer number:  34
# 34 is a failing score

# %%
num = int (input ('Put an integer number: '))
if num > 0:
    print ('{} is a positive number'.format(num))
elif num < 0:
    print ('{} is a negative number'.format(num))
else:
    print ('It is zero')
# Out:
# Put an integer number:  0
# It is zero

# %%
year_ = input ('Put a year: ')
try:
    year = int(year_)
except:
    year = -1 

if year != -1: 
    if year % 4 == 0 and year % 100 != 0:
        print ('{} is a leap year'.format (year))
    elif year % 100 == 0 and year % 400 == 0:
        print ('{} is a leap year'.format (year))
    else:
        print ('{} is not a leap year'.format (year))
else:
    print ('Put year in a correct format')
# Out:
# Put a year:  2000i
# Put year in a correct format
