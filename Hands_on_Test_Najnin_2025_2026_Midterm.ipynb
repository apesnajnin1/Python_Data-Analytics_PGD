# %%
# Answer to tha Q. no. 1
# Design and Implement a menu-driven Calculator Program
def Addition(p, q):
  sum = p + q
  return sum

def Subtraction(p, q):
  diff = p - q
  return diff

def Multiplication(p, q):
  mul = p * q
  return mul

def Division(p, q):
  div = p / q
  return div

while True:
  x = int(input("Enter first number: "))
  y = int(input("Enter second number: "))

  choice = int(input("Enter your choice: "))
  # 1: Addition
  # 2: Subtraction
  # 3: Multiplication
  # 4: Division
  # 5: Exit

  if choice == 1:
    print( 'The Summation is: {}'.format(Addition(x, y)))
  elif choice == 2:
    print( 'The Subtraction is: {}'.format(Subtraction(x, y)))
  elif choice == 3:
    print( 'The Multiplication is: {}'.format(Multiplication(x, y)))
  elif choice == 4:
    print( 'The Division is: {}'.format(Division(x, y)))
  elif choice == 5:
    print('Thanks to use this Menu-driven Calculator')
    break
  else:
    print('Invalid Choice')
    break
# Out:
# Enter first number: 6
# Enter second number: 3
# Enter your choice: 4
# The Division is: 2.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-198642794.py in <cell line: 0>()
#      18
#      19 while True:
# ---> 20   x = int(input("Enter first number: "))
#      21   y = int(input("Enter second number: "))
#      22
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
# ...

# %%
# Answer to the Question no. 2
def sort(arr):
  n = len(arr)

  for i in range (n-1):
    for j in range (n-1-i):
      # Compare adjacent elements
      if arr[j] > arr[j+1]:
        # Swap if they are in the wrong order
        arr[j], arr[j+1] = arr[j+1], arr[j]
  return arr

# Example usage
data = [5, 1, 4, 2, 8]
print ("Before sorting: ", data)

sort(data)

print ("After sorting: ", data)
# Out:
# Before sorting:  [5, 1, 4, 2, 8]
# After sorting:  [1, 2, 4, 5, 8]

# %%
# SUmmation of Factorials
def factorial(m):
     fact = 1
     for i in range (1, m+1):
       fact = fact*i
     return fact

def sum(x):
  sum = 0
  for i in range (1, x+1):
    print(factorial(i) )
    sum = sum + factorial(i)
  return sum


# Summation of Fctorials

n = int(input('input the value of n:'))
factorial_sum = sum(n)
print('The factorial series summation is: ', factorial_sum)
# Out:
# input the value of n:3
# 1
# 2
# 6
# The factorial series summation is:  9
